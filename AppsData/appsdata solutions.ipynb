# %%
import pandas as pd
import numpy as np

# %%
a = np.random.randn(5,5)

# %%
a[1:4,:4] = 1.0

# %%
a
# Out:
# array([[-0.49831465, -0.01649794, -1.54498966,  1.69497096,  0.16924359],
#        [ 1.        ,  1.        ,  1.        ,  1.        , -0.38855967],
#        [ 1.        ,  1.        ,  1.        ,  1.        ,  0.66591371],
#        [ 1.        ,  1.        ,  1.        ,  1.        , -1.33112643],
#        [-1.97586882,  0.4866196 , -0.15518369, -1.00989534,  1.73574729]])

# %%
data = pd.read_excel('appsData.xlsx')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite ?€? FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
data.dropna(subset = ['Type'], inplace = True)

# %%
data['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
data.isnull().any()
# Out:
# App                True
# Category          False
# Rating             True
# Reviews           False
# Size              False
# Installs          False
# Type              False
# Price             False
# Content Rating    False
# Genres            False
# Last Updated      False
# Current Ver        True
# Android Ver        True
# dtype: bool

# %%
(data['Price']<0).any()
# Out:
# False

# %%
mask1 = (data['Type'] == 'Free') & (data['Price'] != 0.0)
mask2 = (data['Type'] == 'Paid') & (data['Price'] == 0.0)
data[mask1]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
a =data[data['Rating'].isnull()]['App'].count()

# %%
b=data['App'].count()

# %%
n = a/b

# %%
"{:.1%}".format(n)
# Out:
# '13.6%'

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data['Last Updated'].dtype
# Out:
# dtype('<M8[ns]')

# %%
data.groupby(data['Last Updated'].dt.year).size().sort_values(ascending = False)
# Out:
# Last Updated
# 2018    7349
# 2017    1867
# 2016     804
# 2015     459
# 2014     209
# 2013     110
# 2012      26
# 2011      15
# 2010       1
# dtype: int64

# %%
install = data[data['Reviews'] >= 100]

# %%
a = install.groupby('Installs')['Rating'].mean()

# %%
a.reindex(index = ['500+','1,000+'])
# Out:
# Installs
# 500+      4.633333
# 1,000+    4.397403
# Name: Rating, dtype: float64

# %%
data.groupby('Genres')['Reviews'].sum().sort_values(ascending=False).head(10)
# Out:
# Genres
# Communication    815462260
# Social           621241422
# Casual           412078863
# Action           350303953
# Arcade           336990433
# Strategy         327198471
# Tools            272842727
# Photography      213516650
# Sports           192877617
# Shopping         115041222
# Name: Reviews, dtype: int64

# %%
pd.crosstab(data['Type'],data['Content Rating'])
# Out:
# Content Rating  Adults only 18+  Everyone  Everyone 10+  Mature 17+  Teen  \
# Type
# Free                          3      8020           380         479  1156
# Paid                          0       695            33          20    52
#
# Content Rating  Unrated
# Type
# Free                  2
# Paid                  0

# %%
data.pivot_table('Price', index = 'Category', columns = 'Content Rating').fillna('Not Applicable')
# Out:
# Content Rating      Adults only 18+  Everyone    Everyone 10+      Mature 17+  \
# Category
# ART_AND_DESIGN       Not Applicable  0.097869             0.0  Not Applicable
# AUTO_AND_VEHICLES    Not Applicable  0.162289             0.0  Not Applicable
# BEAUTY               Not Applicable  0.000000             0.0             0.0
# BOOKS_AND_REFERENCE  Not Applicable  0.578119             0.0             0.0
# BUSINESS             Not Applicable  0.416337             0.0             0.0
# COMICS                          0.0  0.000000             0.0             0.0
# COMMUNICATION        Not Applicable  0.238116  Not Applicable           0.099
# DATING               Not Applicable  0.475238  Not Applicable        0.079453
# EDUCATION            Not Applicable  0.124722             0.0             0.0
# ENTERTAINMENT        Not Applicable  0.127949             0.0        0.332222
# EVENTS               Not Applicable  2.075283             0.0  Not Applicable
# ...

# %%
data.pivot_table('Reviews', index = ['Content Rating','Type'], columns = data['Last Updated'].dt.year).fillna('Not Applicable')
# Out:
# Last Updated                    2010            2011            2012  \
# Content Rating  Type
# Adults only 18+ Free  Not Applicable  Not Applicable  Not Applicable
# Everyone        Free          1415.0          5218.0    14066.421053
#                 Paid  Not Applicable      102.666667            43.6
# Everyone 10+    Free  Not Applicable         38767.0  Not Applicable
#                 Paid  Not Applicable  Not Applicable  Not Applicable
# Mature 17+      Free  Not Applicable  Not Applicable          1696.0
#                 Paid  Not Applicable  Not Applicable  Not Applicable
# Teen            Free  Not Applicable        144545.0  Not Applicable
#                 Paid  Not Applicable  Not Applicable  Not Applicable
# Unrated         Free  Not Applicable  Not Applicable          1186.0
#
# Last Updated                    2013            2014            2015  \
# Content Rating  Type
# Adults only 18+ Free  Not Applicable  Not Applicable  Not Applicable
# ...

# %%
import pandas as pd
import numpy as np

# %%
z = np.random.randn(6,5)
z.sort(1)

# %%
z
# Out:
# array([[-0.95286291, -0.80014047, -0.78773416, -0.60940241, -0.00478896],
#        [-1.69489647, -0.36175171,  0.01530691,  0.60319593,  1.18856516],
#        [-0.97977572,  0.3556122 ,  0.77476496,  1.57983821,  2.21461965],
#        [-1.51435042, -1.33541112, -0.73449592, -0.66244098, -0.43128808],
#        [-0.11186063,  0.50795665,  0.99078997,  1.19201683,  1.95942495],
#        [-2.49377559, -0.42693703,  0.08862676,  0.18067279,  1.12873308]])

# %%
nba = pd.read_csv('nba.csv')
nba.isnull().any()
# Out:
# Unnamed: 0                  False
# Team                        False
# Game                        False
# Date                        False
# Home                        False
# Opponent                    False
# WINorLOSS                   False
# TeamPoints                  False
# OpponentPoints              False
# FieldGoals                  False
# FieldGoalsAttempted         False
# FieldGoals.                 False
# X3PointShots                False
# X3PointShotsAttempted       False
# X3PointShots.               False
# FreeThrows                  False
# FreeThrowsAttempted         False
# FreeThrows.                 False
# OffRebounds                 False
# TotalRebounds               False
# Assists                     False
# Steals                      False
# Blocks                      False
# Turnovers                   False
# TotalFouls                  False
# Opp.FieldGoals              False
# Opp.FieldGoalsAttempted     False
# ...

# %%
nba['Date'].dtype
# Out:
# dtype('O')

# %%
nba['Date'] = pd.to_datetime(nba['Date'])
nba['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
nba['Date'] = nba['Date'].dt.year
nba
# Out:
#       Unnamed: 0 Team  Game  Date  Home Opponent WINorLOSS  TeamPoints  \
# 0              1  ATL     1  2014  Away      TOR         L         102
# 1              2  ATL     2  2014  Home      IND         W         102
# 2              3  ATL     3  2014  Away      SAS         L          92
# 3              4  ATL     4  2014  Away      CHO         L         119
# 4              5  ATL     5  2014  Home      NYK         W         103
# ...          ...  ...   ...   ...   ...      ...       ...         ...
# 9835       78119  WAS    78  2018  Away      HOU         L         104
# 9836       79119  WAS    79  2018  Away      CLE         L         115
# 9837       80119  WAS    80  2018  Home      ATL         L          97
# 9838       81124  WAS    81  2018  Home      BOS         W         113
# 9839       82119  WAS    82  2018  Away      ORL         L          92
#
#       OpponentPoints  FieldGoals  ...  Opp.FreeThrows  \
# 0                109          40  ...              27
# ...

# %%
team = input('Enter a team:')
# Out:
# Enter a team:HOU

# %%
hou = nba[nba['Team']==team]

# %%
hou.groupby(['Date','Home'])['TeamPoints'].mean()
# Out:
# Date  Home
# 2014  Away    105.285714
#       Home     97.470588
# 2015  Away    103.666667
#       Home    106.534884
# 2016  Away    110.622222
#       Home    111.526316
# 2017  Away    113.105263
#       Home    117.500000
# 2018  Away    109.120000
#       Home    111.454545
# Name: TeamPoints, dtype: float64

# %%
nba
# Out:
#       Unnamed: 0 Team  Game                          Date  Home Opponent  \
# 0              1  ATL     1 1970-01-01 00:00:00.000002014  Away      TOR
# 1              2  ATL     2 1970-01-01 00:00:00.000002014  Home      IND
# 2              3  ATL     3 1970-01-01 00:00:00.000002014  Away      SAS
# 3              4  ATL     4 1970-01-01 00:00:00.000002014  Away      CHO
# 4              5  ATL     5 1970-01-01 00:00:00.000002014  Home      NYK
# ...          ...  ...   ...                           ...   ...      ...
# 9835       78119  WAS    78 1970-01-01 00:00:00.000002018  Away      HOU
# 9836       79119  WAS    79 1970-01-01 00:00:00.000002018  Away      CLE
# 9837       80119  WAS    80 1970-01-01 00:00:00.000002018  Home      ATL
# 9838       81124  WAS    81 1970-01-01 00:00:00.000002018  Home      BOS
# 9839       82119  WAS    82 1970-01-01 00:00:00.000002018  Away      ORL
#
#      WINorLOSS  TeamPoints  OpponentPoints  FieldGoals  ...  Opp.FreeThrows  \
# ...

# %%
nba1 = pd.read_csv('nba.csv')

# %%
nba1
# Out:
#       Unnamed: 0 Team  Game        Date  Home Opponent WINorLOSS  TeamPoints  \
# 0              1  ATL     1  2014-10-29  Away      TOR         L         102
# 1              2  ATL     2  2014-11-01  Home      IND         W         102
# 2              3  ATL     3  2014-11-05  Away      SAS         L          92
# 3              4  ATL     4  2014-11-07  Away      CHO         L         119
# 4              5  ATL     5  2014-11-08  Home      NYK         W         103
# ...          ...  ...   ...         ...   ...      ...       ...         ...
# 9835       78119  WAS    78  2018-04-03  Away      HOU         L         104
# 9836       79119  WAS    79  2018-04-05  Away      CLE         L         115
# 9837       80119  WAS    80  2018-04-06  Home      ATL         L          97
# 9838       81124  WAS    81  2018-04-10  Home      BOS         W         113
# 9839       82119  WAS    82  2018-04-11  Away      ORL         L          92
#
# ...

# %%
nba1['Date'] = pd.to_datetime(nba1['Date'])
nba1['Date'] = nba1['Date'].dt.year

# %%
nba1
# Out:
#       Unnamed: 0 Team  Game  Date  Home Opponent WINorLOSS  TeamPoints  \
# 0              1  ATL     1  2014  Away      TOR         L         102
# 1              2  ATL     2  2014  Home      IND         W         102
# 2              3  ATL     3  2014  Away      SAS         L          92
# 3              4  ATL     4  2014  Away      CHO         L         119
# 4              5  ATL     5  2014  Home      NYK         W         103
# ...          ...  ...   ...   ...   ...      ...       ...         ...
# 9835       78119  WAS    78  2018  Away      HOU         L         104
# 9836       79119  WAS    79  2018  Away      CLE         L         115
# 9837       80119  WAS    80  2018  Home      ATL         L          97
# 9838       81124  WAS    81  2018  Home      BOS         W         113
# 9839       82119  WAS    82  2018  Away      ORL         L          92
#
#       OpponentPoints  FieldGoals  ...  Opp.FreeThrows  \
# 0                109          40  ...              27
# ...

# %%
_2017 = nba1[nba1['Date']==2017]
pd.crosstab(_2017['Team'],_2017['WINorLOSS'])
# Out:
# WINorLOSS   L   W
# Team
# ATL        49  36
# BOS        25  63
# BRK        61  25
# CHI        46  38
# CHO        54  30
# CLE        36  50
# DAL        50  36
# DEN        40  45
# DET        40  42
# GSW        18  67
# HOU        27  55
# IND        40  45
# LAC        36  45
# LAL        56  25
# MEM        50  33
# MIA        34  50
# MIL        39  45
# MIN        43  43
# NOP        45  38
# NYK        52  33
# OKC        39  46
# ORL        59  26
# PHI        49  37
# PHO        58  28
# POR        37  45
# SAC        55  30
# SAS        27  59
# TOR        31  53
# UTA        39  46
# WAS        33  54

# %%
nba1.pivot_table('TeamPoints', index = 'Team', columns = 'Date')
# Out:
# Date        2014        2015        2016        2017        2018
# Team
# ATL   102.161290  102.470588  102.827160  103.941176  102.934783
# BOS   103.344828  101.352941  106.880952  106.659091  104.547619
# BRK    96.806452   98.108434  102.134146  106.383721  105.934783
# CHI   102.468750  100.225000  101.406977  102.797619  104.826087
# CHO    95.272727   96.925000  104.329412  104.607143  111.347826
# CLE   101.500000  102.487500  108.500000  110.011628  111.478261
# DAL   109.606061  102.259259   99.392857  100.406977  103.431818
# DEN   101.500000  100.433735  105.487805  111.294118  112.217391
# DET    95.967742  100.571429  100.750000  102.878049  104.978723
# GSW   108.066667  112.190476  116.059524  115.129412  112.066667
# HOU   101.000000  105.117647  111.036145  115.463415  110.212766
# IND    94.878788  100.456790  102.726190  106.317647  104.400000
# LAC   105.878788  105.481928  106.654762  107.604938  111.574468
# ...

# %%
_2017['Diff'] = _2017['TeamPoints'] - _2017['OpponentPoints']
# Out:
# /var/folders/gt/ndv7xrg17c95c6s42ycl5ch40000gn/T/ipykernel_2599/686184369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _2017['Diff'] = _2017['TeamPoints'] - _2017['OpponentPoints']

# %%
_2017.groupby('Team')['Diff'].mean().sort_values(ascending=False)
# Out:
# Team
# GSW    10.423529
# HOU     6.012195
# SAS     5.360465
# TOR     4.285714
# BOS     3.977273
# WAS     2.839080
# LAC     2.049383
# UTA     1.952941
# DEN     1.776471
# MIA     1.619048
# POR     1.536585
# CLE     1.488372
# OKC     1.329412
# MIN     0.511628
# IND     0.458824
# DET    -0.560976
# NOP    -0.795181
# MIL    -1.285714
# MEM    -1.421687
# CHO    -1.583333
# DAL    -1.651163
# ATL    -1.870588
# CHI    -1.940476
# NYK    -2.470588
# PHI    -2.860465
# BRK    -4.337209
# PHO    -5.581395
# LAL    -5.913580
# SAC    -6.458824
# ORL    -6.988235
# Name: Diff, dtype: float64

# %%
nba1.pivot_table('Diff', index= 'Team', columns = 'Date', aggfunc=['max','min'])
# Out:
#       max                      min
# Date 2014 2015 2016 2017 2018 2014 2015 2016 2017 2018
# Team
# ATL    30   32   38   46   26  -33  -25  -44  -34  -29
# BOS    22   39   30   30   30  -22  -31  -25  -23  -22
# BRK    31   37   18   35   28  -25  -39  -34  -39  -34
# CHI    25   35   32   47   19  -18  -25  -31  -49  -39
# CHO    28   28   34   40   61  -30  -39  -29  -27  -28
# CLE    33   39   38   32   25  -29  -39  -34  -35  -34
# DAL    53   30   27   49   34  -21  -33  -38  -42  -27
# DEN    25   29   19   32   33  -30  -43  -33  -30  -32
# DET    23   39   36   30   34  -22  -24  -43  -33  -36
# GSW    40   50   45   49   46  -14  -23  -32  -22  -40
# HOU    19   36   49   39   32  -26  -28  -31  -29  -17
# IND    25   37   24   25   39  -23  -22  -37  -28  -26
# LAC    28   39   40   42   23  -17  -30  -26  -46  -22
# LAL    15   18   27   27   25  -34  -40  -48  -49  -37
# MEM    26   36   34   20   18  -14  -50  -49  -25  -61
# ...

# %%
a = nba[nba['WINorLOSS']=='W']
a.groupby(['Team','Date']).size()
# Out:
# Team  Date
# ATL   1970-01-01 00:00:00.000002014    23
#       1970-01-01 00:00:00.000002015    58
#       1970-01-01 00:00:00.000002016    44
#       1970-01-01 00:00:00.000002017    36
#       1970-01-01 00:00:00.000002018    14
#                                        ..
# WAS   1970-01-01 00:00:00.000002014    22
#       1970-01-01 00:00:00.000002015    38
#       1970-01-01 00:00:00.000002016    43
#       1970-01-01 00:00:00.000002017    54
#       1970-01-01 00:00:00.000002018    22
# Length: 150, dtype: int64
